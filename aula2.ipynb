# %% [markdown]
# # Pesquisa Estilo Musical em Sala de Aula
# - rock
# - hip hop
# - mpb
# - reggae
# - breakcore
# - sertanejo
# - gospel
# - eletronica

# %% [markdown]
# Objetivo: usar a inteligência artifical na sala de aula, gerando músicas com ritmos que os alunos terão uma experiência imersiva na aula.

# %%
! pip install scipy
# Out:
# ...
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    - -------------------------------------- 2.1/44.5 MB 11.8 MB/s eta 0:00:04
#    --- ------------------------------------ 3.9/44.5 MB 10.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.5/44.5 MB 7.5 MB/s eta 0:00:06
#    ---- ----------------------------------- 4.7/44.5 MB 7.0 MB/s eta 0:00:06
#    ---- ----------------------------------- 5.2/44.5 MB 5.3 MB/s eta 0:00:08
#    ----- ---------------------------------- 5.8/44.5 MB 4.8 MB/s eta 0:00:09
#    ----- ---------------------------------- 6.3/44.5 MB 4.5 MB/s eta 0:00:09
#    ------ --------------------------------- 7.1/44.5 MB 4.3 MB/s eta 0:00:09
#    ------ --------------------------------- 7.6/44.5 MB 4.2 MB/s eta 0:00:09
#    ------- -------------------------------- 8.4/44.5 MB 4.2 MB/s eta 0:00:09
#    -------- ------------------------------- 9.4/44.5 MB 4.2 MB/s eta 0:00:09
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

# %%
df_m = pd.read_csv("Datasets/pesquisa.csv")

# %%
df_m.head()
# Out:
#   Carimbo de data/hora  Avalie os estilos musicais [rock]  \
# 0  21/08/2024 10:03:25                                  3
# 1  21/08/2024 10:04:39                                  5
# 2  21/08/2024 10:04:52                                  1
# 3  21/08/2024 10:04:53                                  1
# 4  21/08/2024 10:04:55                                  5
#
#    Avalie os estilos musicais [hip hop]  Avalie os estilos musicais [mpb]  \
# 0                                     1                                 1
# 1                                     3                                 5
# 2                                     5                                 1
# 3                                     5                                 4
# 4                                     4                                 3
#
#    Avalie os estilos musicais [reggae]  Avalie os estilos musicais [funk]  \
# 0                                    1                                  1
# ...

# %%
df_m.columns = ["data_hora", "rock", "hiphop", "mpb", "reggae", "funk", "sertanejo", "gospel", "eletronica"]

# %%
df_m = df_m.drop(columns="data_hora")

# %%
sns.histplot(df_m)
# Out:
# <Axes: ylabel='Count'>

# %%
df_m.plot(kind='kde', figsize=[20, 8], grid=True, colormap="viridis_r")
# Out:
# <Axes: ylabel='Density'>

# %%
df_m.plot(kind="scatter", x=7, y=7, ylabel=10, xlabel=["eletronica", "rock"])
# Out:
# <Axes: xlabel="['eletronica', 'rock']", ylabel='10'>

# %%
df_sum = df_m.sum()
df_sum.plot(kind="barh")
# Out:
# <Axes: >

# %%
df_m.plot(kind="box", figsize=[20,10], grid=True, )
# Out:
# <Axes: >
